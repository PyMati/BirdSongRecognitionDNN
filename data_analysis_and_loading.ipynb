# %%
import pandas as pd
import os
import numpy as np

# %%
data = {}
for klass in os.listdir("data"):
    if os.path.isdir("data/" + klass):
        data[klass] = os.listdir("data/" + klass)

# %%
df = pd.read_csv("data/train_mod.csv")
for col in df.columns:
    print(col)
# Out:
# rating
# playback_used
# ebird_code
# channels
# date
# pitch
# duration
# filename
# speed
# species
# number_of_notes
# title
# secondary_labels
# bird_seen
# sci_name
# location
# latitude
# sampling_rate
# type
# elevation
# description
# bitrate_of_mp3
# file_type
# volume
# background
# xc_id
# url
# country
# author
# primary_label
# longitude
# length
# time
# recordist
# license
# resampled_sampling_rate
# resampled_filename
# resampled_channels

# %%
data.keys()
# Out:
# dict_keys(['evegro', 'canwre', 'comrav', 'cliswa', 'carwre', 'comgol', 'daejun', 'calgul', 'caster1', 'comgra', 'chiswi', 'easblu', 'chukar', 'chispa', 'canwar', 'casvir', 'comnig', 'eursta', 'comloo', 'comter', 'fiespa', 'coohaw', 'foxspa', 'comred', 'easpho', 'fiscro', 'eastow', 'eawpew', 'dowwoo', 'commer', 'dusfly', 'cangoo', 'cowscj1', 'clanut', 'doccor', 'calqua', 'cedwax', 'comyel', 'camwar', 'eucdov', 'cacwre', 'chswar', 'coshum', 'eargre', 'easmea', 'casfin', 'easkin'])

# %%
df = df[df["ebird_code"].isin(os.listdir("data"))]

# %%
df.head()
# Out:
#       rating playback_used ebird_code    channels        date          pitch  \
# 4524     4.0           NaN     cacwre    1 (mono)  2006-07-15          level
# 4525     3.5            no     cacwre    1 (mono)  2013-04-11  Not specified
# 4526     4.0            no     cacwre  2 (stereo)  2013-05-10  Not specified
# 4527     4.0            no     cacwre  2 (stereo)  2013-05-10  Not specified
# 4528     4.0            no     cacwre    1 (mono)  2013-04-19  Not specified
#
#       duration      filename          speed      species  ...  \
# 4524        27   XC11493.mp3          level  Cactus Wren  ...
# 4525       150  XC132895.mp3  Not specified  Cactus Wren  ...
# 4526        33  XC140127.mp3  Not specified  Cactus Wren  ...
# 4527        22  XC140128.mp3  Not specified  Cactus Wren  ...
# 4528        52  XC146149.mp3  Not specified  Cactus Wren  ...
#
#                author                                primary_label  longitude  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3928 entries, 4524 to 8451
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   rating                   3928 non-null   float64
#  1   playback_used            3619 non-null   object
#  2   ebird_code               3928 non-null   object
#  3   channels                 3928 non-null   object
#  4   date                     3928 non-null   object
#  5   pitch                    3928 non-null   object
#  6   duration                 3928 non-null   int64
#  7   filename                 3928 non-null   object
#  8   speed                    3928 non-null   object
#  9   species                  3928 non-null   object
#  10  number_of_notes          3928 non-null   object
#  11  title                    3928 non-null   object
#  12  secondary_labels         3928 non-null   object
#  13  bird_seen                3619 non-null   object
# ...

# %%
df.describe()
# Out:
#             rating     duration          xc_id  resampled_sampling_rate
# count  3928.000000  3928.000000    3928.000000                   3928.0
# mean      3.978997    53.284878  290184.977342                  32000.0
# std       1.153268    72.705041  128291.477027                      0.0
# min       0.000000     0.000000   11462.000000                  32000.0
# 25%       3.500000    16.000000  175323.250000                  32000.0
# 50%       4.000000    32.000000  304604.500000                  32000.0
# 75%       5.000000    66.000000  394914.250000                  32000.0
# max       5.000000  2283.000000  505611.000000                  32000.0

# %%
print("Species distribution:")
print(df["species"].value_counts())
# Out:
# Species distribution:
# Cactus Wren                  100
# Chestnut-sided Warbler       100
# Field Sparrow                100
# Evening Grosbeak             100
# Eurasian Collared Dove       100
# Eastern Wood Pewee           100
# Eastern Towhee               100
# Eastern Meadowlark           100
# Downy Woodpecker             100
# Dark-eyed Junco              100
# Common Yellowthroat          100
# Common Tern                  100
# Common Redpoll               100
# Common Grackle               100
# Northern Raven               100
# Red Fox Sparrow              100
# Canada Goose                 100
# Canada Warbler               100
# Caspian Tern                 100
# Canyon Wren                  100
# Chipping Sparrow             100
# Carolina Wren                100
# American Dusky Flycatcher     98
# Eastern Bluebird              96
# Eastern Phoebe                91
# Cooper's Hawk                 90
# California Quail              90
# ...

# %%
print("\nSong vs Call distribution:")
print(df.groupby("type")["type"].count())
# Out:
# Song vs Call distribution:
# type
# "du-hic", call                      1
# "grunt", call, song                 1
# 1-syllable song from adult male.    1
# 2 males countersinging, song        1
# Alarm Song, song                    1
#                                    ..
# wing sound                          2
# wing whirr                          1
# wing whistle                        2
# wing-noise                          1
# wings during flight                 1
# Name: type, Length: 324, dtype: int64

# %%
print("\nBird seen vs not seen:")
print(df.groupby("bird_seen")["bird_seen"].count())
# Out:
# Bird seen vs not seen:
# bird_seen
# no      587
# yes    3032
# Name: bird_seen, dtype: int64

# %%
print("\nTop 5 longest recordings:")
print(df.sort_values("duration", ascending=False)["duration"].head())
# Out:
# Top 5 longest recordings:
# 6468    2283
# 7379     797
# 5117     680
# 4850     625
# 8282     595
# Name: duration, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 6))
sns.countplot(x="species", data=df)
plt.title("Species Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 6))
sns.countplot(x="ebird_code", data=df)
plt.title("Species Distribution")
plt.xticks(rotation=90)
plt.show()
